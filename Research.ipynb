# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Prep

# %%
df14 = pd.read_csv("data/laser_incidents_2010-2014.csv")
df14.drop(df14.index[-1], inplace=True) # drop last row with "2014 total"
df14.drop("No. A/C", axis=1, inplace=True) # drop number of aircraft column
df14.rename(columns={'DATE': 'Incident Date',
                    'TIME (UTC)' : 'Incident Time',
                    'Aircraft ID' : 'Flight ID',
                    'TYPE A/C' : 'Aircraft',
                    'ALT' : 'Altitude',
                    'MAJOR CITY' : 'Airport',
                    'COLOR' : 'Laser Color',
                    'Injury Reported' : 'Injury',
                    'CITY' : 'City',
                    'STATE' : 'State'}, inplace=True) # rename columns consistent with other columns
df14
# Out:
#      Incident Date  Incident Time Flight ID             Aircraft Altitude  \
# 0         1-Jan-14            8.0   CHQ6045                 E145     8000
# 1         1-Jan-14           35.0       PSA                 CRJ2     2100
# 2         1-Jan-14          202.0    SWA563                 B737     4200
# 3         1-Jan-14          235.0   RPA3242                 E175    FL240
# 4         1-Jan-14          259.0   AAL1153                 B738    12000
# ...            ...            ...       ...                  ...      ...
# 3889     31-Dec-14          443.0    AAL128  B737 (BOEING - 737-     2500
# 3890     31-Dec-14          445.0    N310PJ  LJ35 (GATES LEARJET      300
# 3891     31-Dec-14          445.0   SKW4675  CRJ2 (CANADAIR - Ch     4000
# 3892     31-Dec-14          515.0    EJA204  CRJ2 (CANADAIR - Ch     4000
# 3893     31-Dec-14         2344.0    N844RC                 GALX      120
#
#      Airport Laser Color Injury          City                 State
# ...

# %%
df15 = pd.read_csv("data/reported_laser_illumination_incidents_CY_2015.csv")
df15 = df15.drop(df15.columns[-2:], axis=1) # drop nonexistent columns
df15
# Out:
#      Incident Date  Incident Time Flight ID             Aircraft Altitude  \
# 0         1-Jan-15             16   SWA3490  B737 (BOEING - 737-     3500
# 1         1-Jan-15             19    NKS948  A320 (AIRBUS - A-32    10000
# 2         1-Jan-15             46   DAL1146  B772 (BOEING - 777-    10000
# 3         1-Jan-15            200     AAL99  B738 (BOEING - 737-    10000
# 4         1-Jan-15            318    NKS265                 A320      500
# ...            ...            ...       ...                  ...      ...
# 7341     31-Dec-15            525    VRD917  A320 (AIRBUS - A-32     8000
# 7342     31-Dec-15            623   DAL2371  B738 (BOEING - 737-    11000
# 7343     31-Dec-15           1111   Unknown              Unknown     2000
# 7344     31-Dec-15           1147    UAL197                 B737      300
# 7345     31-Dec-15           2314    EJA336               E55P/L     1000
#
#      Airport Laser Color Injury               City      State
# ...

# %%
df16 = pd.read_csv("data/reported_laser_illumination_incidents_CY_2016.csv")
df16.drop("Aviation Altitude", axis=1, inplace=True) # drop empty column
df16
# Out:
#      Incident Date  Incident Time Flight ID Aircraft Altitude Airport  \
# 0         1-Jan-16              4      MED4     BK17     2000    UNKN
# 1         1-Jan-16              7   SWA5431     B737     6000     BWI
# 2         1-Jan-16             55    ASA787     B739     4000     MSY
# 3         1-Jan-16             58   CPZ5929     E170     9000     DEN
# 4         1-Jan-16            107    N785AM     BE20     4000     SEA
# ...            ...            ...       ...      ...      ...     ...
# 7393     31-Dec-16            528   UPS1075    MD11     17000     IND
# 7394     31-Dec-16            820   SWA5165    B737      5600     MYV
# 7395     31-Dec-16           1157   ASH6179     E175    11000     IAD
# 7396     31-Dec-16           2222   JIA5299     CRJ2     3000     PHL
# 7397     31-Dec-16           2224   SWA3013    B737     12000     MRY
#
#      Laser Color Injury             City                 State
# 0          Green     No             UNKN                  UNKN
# ...

# %%
df17 = pd.read_csv("data/reported_laser_illumination_incidents_CY_2017.csv")
df17
# Out:
#      Incident Date  Incident Time Flight ID Aircraft Altitude Airport  \
# 0         1-Jan-17             11    NKS423     A320     1500     MCO
# 1         1-Jan-17            104   ASH5771     CRJ9     7200     DTO
# 2         1-Jan-17            145   TCF2803     E170     5500     FDK
# 3         1-Jan-17            205    JBU543     E190     2000     PBI
# 4         1-Jan-17            227   ASQ2821     CRJ2     8000     SAF
# ...            ...            ...       ...      ...      ...     ...
# 6748     31-Dec-17            330   ASH6112     E755    35000     PAH
# 6749     31-Dec-17            347   ENY3665     E170    20000     PMM
# 6750     31-Dec-17            350   SWA3383     B737     2300     OAK
# 6751     31-Dec-17            358   UPS6859    B763     14000     PHX
# 6752     31-Dec-17           2226   JIA5078     CRJ9     1400     MEM
#
#      Laser Color Injury             City       State
# 0          Green     No          Orlando     Florida
# ...

# %%
df18 = pd.read_csv("data/Laser_Report_2018_final.csv")
df18
# Out:
#      Incident Date Incident Time Flight ID Aircraft Altitude Airport  \
# 0         1-Jan-18          0015      UAL4     B77W     1200     IAH
# 1         1-Jan-18          0032    AAL916     A319     7000     TMB
# 2         1-Jan-18          0257   SKW4957     CRJ7     7000     SLC
# 3         1-Jan-18          0302   CPZ6091     E75L     1000     LAX
# 4         1-Jan-18          0318   UPS5901     B747    10000     SDF
# ...            ...           ...       ...      ...      ...     ...
# 5658     31-Dec-18          0631   SWA5532     B737    11300     BOI
# 5659     31-Dec-18          0645    DAL781     B739    13000     MYV
# 5660     31-Dec-18          1310    OXF745     DA42     1900     FFZ
# 5661     31-Dec-18          1419   DAL2810     B712    17000     LVK
# 5662     31-Dec-18          1430    N852AL   PC12/G     8000     RDM
#
#      Laser Color Injury            City       State
# 0          Green     No         Houston       Texas
# ...

# %%
df19 = pd.read_csv("data/Laser_Report_2019_final.csv")
df19
# Out:
#      Incident Date  Incident Time Flight ID Aircraft Altitude Airport  \
# 0         1-Jan-19             35      N3EG     C421     2500     SAT
# 1         1-Jan-19             43   RPA3469     E75S     4000     IAH
# 2         1-Jan-19             44   UAL1607     A319     4000     IAH
# 3         1-Jan-19            110    N205TM     BE20     2500     HDC
# 4         1-Jan-19            115   JIA5233     CRJ9     2000     JAX
# ...            ...            ...       ...      ...      ...     ...
# 6131     31-Dec-19            845   ASH5861     CRJ9     3000     JAN
# 6132     31-Dec-19            929      N22P     CRUZ     2500     HNL
# 6133     31-Dec-19           2310    GTH530     GLF4      500     SJU
# 6134     31-Dec-19           2312   AMF6916      SW4      600     SJU
# 6135     31-Dec-19           2327    N715TH     C172     3000     CHO
#
#      Laser Color Injury              City        State
# 0          Green     No       San Antonio        Texas
# ...

# %%
df20 = pd.read_csv("data/Laser_Report_2020.csv")
df20
# Out:
#      Incident Date  Incident Time Flight ID Aircraft Altitude Airport  \
# 0         1-Jan-20          148.0    N424RP   DA42/A     8500     SBA
# 1         1-Jan-20          155.0   AMF1829     B190    40000     SSF
# 2         1-Jan-20          214.0   NKS1881     A320     2500     TPA
# 3         1-Jan-20          217.0   FDX3873     B763     3000     DFW
# 4         1-Jan-20          218.0   SWA3635     B739    11000     MOD
# ...            ...            ...       ...      ...      ...     ...
# 6847     31-Dec-20          943.0    N6109L      AA1     2000     HNL
# 6848     31-Dec-20         1035.0    LBQ875     PC12     2000     ROA
# 6849     31-Dec-20         1126.0   FDX1755     A306     1000     IAD
# 6850     31-Dec-20         1133.0   FDX1874     B752     8000     LAS
# 6851     31-Dec-20         1158.0    AAY984     A320     4000     PIE
#
#      Laser Color Injury                       City                 State
# ...

# %%
df21 = pd.read_csv("data/Laser-Report-2021-FINAL.csv", skiprows=1)
df21.rename(columns={'FlightID' : 'Flight ID'}, inplace=True) #rename FlightID column
df21
# Out:
#      Incident Date  Incident Time Flight ID Aircraft Altitude Airport  \
# 0         1-Jan-21             48   ASH6151     E75L     2000     SAV
# 1         1-Jan-21             56   SKW3321     E75L    17000     ZOA
# 2         1-Jan-21            102   ACO2204     C208     5000     DSM
# 3         1-Jan-21            125   AMF2521     E120     2000     ONT
# 4         1-Jan-21            140    N149MF     BE9L     4000     ZSE
# ...            ...            ...       ...      ...      ...     ...
# 9718     31-Dec-21            356       CF4     B407     1500     DAL
# 9719     31-Dec-21            540   AAL1956     A21N    32000     ZAB
# 9720     31-Dec-21            645   FFT1427     A320     3000     P50
# 9721     31-Dec-21           1859   ATN3367     B763     3200     SBD
# 9722     31-Dec-21           2200     N98ZA     B407      800     CDW
#
#      Laser Color Injury            City       State
# 0          Green     No        Savannah     Georgia
# ...

# %%
df22 = pd.read_csv("data/Laser_Report_2022 _12.31_FINAL.csv")
df22.rename(columns={'FlightID' : 'Flight ID'}, inplace=True) #rename FlightID column
df22
# Out:
#      Incident Date  Incident Time Flight ID Aircraft Altitude Airport  \
# 0         1-Jan-22            105   AAL2305     A321    28000     ZMP
# 1         1-Jan-22            109    EJA145     GLEX     2000     PBI
# 2         1-Jan-22            118   DAL1013     A320     1000     LAX
# 3         1-Jan-22            120   CFS7686     C208      700     PDX
# 4         1-Jan-22            125    N500MH     SR20     2000     TOA
# ...            ...            ...       ...      ...      ...     ...
# 9452     31-Dec-22            114   SWA3162     B738     7000     D10
# 9453     31-Dec-22            100   NKS1702     A319    14000     ZNY
# 9454     31-Dec-22             49    AAY454     A320    16000     ZJX
# 9455     31-Dec-22             28   JBU1118     E190     3000     A90
# 9456     31-Dec-22              2   JBU1882     E190     4000     I90
#
#         Laser Color Injury               City          State
# 0              Blue     No       Dodge Center      Minnesota
# ...

# %%
df23 = pd.read_csv("data/Laser_Report_2023_through_03-31.csv")
df23.rename(columns={'FlightID' : 'Flight ID'}, inplace=True) #rename FlightID column
df23
# Out:
#      Incident Date  Incident Time Flight ID Aircraft Altitude Airport  \
# 0         1-Jan-23           2330   LN163BF     EC35      800     PGD
# 1         1-Jan-23           2300   EDV4994     CRJ9    13000     N90
# 2         1-Jan-23           2257    N8410L     C172     2800     JQF
# 3         1-Jan-23           1130    AAL605     B38M    16000     ZDC
# 4         1-Jan-23            949    N269ME     C172     1800     HCF
# ...            ...            ...       ...      ...      ...     ...
# 2532     31-Mar-23            121     PDU41     P28R     3500     IND
# 2533     31-Mar-23             52   EDV4654     CRJ9     2700     MKE
# 2534     31-Mar-23             45    N141TN     DV20     1300     ZME
# 2535     31-Mar-23             38    N488BW     S22T     8000     ZJX
# 2536     31-Mar-23             35   AAL1761     A321    18800     ZOB
#
#      Laser Color Injury          City           State
# 0          Green     No   Punta Gorda         Florida
# ...

# %%
df = pd.concat([df14, df15, df16, df17, df18, df19, df20, df21, df22, df23])
df = df.reset_index()
df
# Out:
#        index Incident Date Incident Time Flight ID Aircraft Altitude Airport  \
# 0          0      1-Jan-14           8.0   CHQ6045     E145     8000     CAE
# 1          1      1-Jan-14          35.0       PSA     CRJ2     2100     PHL
# 2          2      1-Jan-14         202.0    SWA563     B737     4200     PHX
# 3          3      1-Jan-14         235.0   RPA3242     E175    FL240     EWR
# 4          4      1-Jan-14         259.0   AAL1153     B738    12000     POM
# ...      ...           ...           ...       ...      ...      ...     ...
# 65754   2532     31-Mar-23           121     PDU41     P28R     3500     IND
# 65755   2533     31-Mar-23            52   EDV4654     CRJ9     2700     MKE
# 65756   2534     31-Mar-23            45    N141TN     DV20     1300     ZME
# 65757   2535     31-Mar-23            38    N488BW     S22T     8000     ZJX
# 65758   2536     31-Mar-23            35   AAL1761     A321    18800     ZOB
#
# ...
